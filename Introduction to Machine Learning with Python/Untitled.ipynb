# %%
pip install jupyterlab_tabnine
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#   Using cached jupyterlab_tabnine-0.0.24-py3-none-any.whl (178 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall jupyterlab_tabnine --y
# Out:
# Found existing installation: jupyterlab-tabnine 0.0.24
# Uninstalling jupyterlab-tabnine-0.0.24:
#   Successfully uninstalled jupyterlab-tabnine-0.0.24
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall lab-extension --y
# Out:
# WARNING: Skipping lab-extension as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall notebook
# Out:
# Found existing installation: notebook 6.5.4
# Uninstalling notebook-6.5.4:
#   Would remove:
#     /opt/conda/envs/anaconda-panel-2023.05-py310/bin/jupyter-bundlerextension
#     /opt/conda/envs/anaconda-panel-2023.05-py310/bin/jupyter-nbextension
#     /opt/conda/envs/anaconda-panel-2023.05-py310/bin/jupyter-notebook
#     /opt/conda/envs/anaconda-panel-2023.05-py310/bin/jupyter-serverextension
#     /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/notebook-6.5.4.dist-info/*
#     /opt/conda/envs/anaconda-panel-2023.05-py310/lib/python3.11/site-packages/notebook/*
#     /opt/conda/envs/anaconda-panel-2023.05-py310/share/applications/jupyter-notebook.desktop
#     /opt/conda/envs/anaconda-panel-2023.05-py310/share/icons/hicolor/scalable/apps/notebook.svg
# Proceed (Y/n)? ^C
# ERROR: Operation cancelled by user
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install jupyter_scheduler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 515.8/515.8 kB 6.7 MB/s eta 0:00:000:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 kB 4.3 MB/s eta 0:00:007 MB/s eta 0:00:01
# ...
#   Using cached nbconvert-7.9.2-py3-none-any.whl (256 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.8 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.3/502.3 kB 6.6 MB/s eta 0:00:000:00:01
# ...
#   Using cached mistune-3.0.2-py3-none-any.whl (47 kB)
# ...
#   WARNING: The scripts jupyter-dejavu and jupyter-nbconvert are installed in '/home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...

# %%
enable --user --py jupyter_scheduler
# Out:
#   Cell In[6], line 1
#     enable --user --py jupyter_scheduler
#                        ^
# SyntaxError: invalid syntax

# %%
pip install jupyter_scheduler
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip uninstall jupyter_scheduler
# Out:
# Found existing installation: jupyter_scheduler 2.1.0
# Uninstalling jupyter_scheduler-2.1.0:
#   Would remove:
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/etc/jupyter/jupyter_notebook_config.d/jupyter_scheduler.json
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/etc/jupyter/jupyter_server_config.d/jupyter_scheduler.json
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/lib/python3.11/site-packages/jupyter_scheduler-2.1.0.dist-info/*
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/lib/python3.11/site-packages/jupyter_scheduler/*
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/share/jupyter/labextensions/@jupyterlab/scheduler/package.json
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/share/jupyter/labextensions/@jupyterlab/scheduler/schemas/@jupyterlab/scheduler/package.json.orig
#     /home/1d78c05e-3e91-4b07-80d5-6517be9590e4/.local/share/jupyter/labextensions/@jupyterlab/scheduler/schemas/@jupyterlab/scheduler/plugin.json
# ...

# %%
pip uninstall jupyter_scheduler --y
# Out:
# Found existing installation: jupyter_scheduler 2.1.0
# Uninstalling jupyter_scheduler-2.1.0:
#   Successfully uninstalled jupyter_scheduler-2.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import scipy as sp
import IPython
import sklearn
import mglearn

# %%
rnd = np.random.RandomState(0)

X_org = rnd.normal(size=(1000,3))
w = rnd.normal(size=3)

df = pd.DataFrame(X_org)
df
# Out:
#             0         1         2
# 0    1.764052  0.400157  0.978738
# 1    2.240893  1.867558 -0.977278
# 2    0.950088 -0.151357 -0.103219
# 3    0.410599  0.144044  1.454274
# 4    0.761038  0.121675  0.443863
# ..        ...       ...       ...
# 995 -0.224092  1.967730  0.447683
# 996 -0.662191 -1.577607 -0.340560
# 997 -1.303220  0.466751  0.161106
# 998  0.320032  2.079177 -0.907466
# 999 -0.192404 -1.212516 -0.080599
#
# [1000 rows x 3 columns]

# %%
plt.hist(X_org[:,0], bins=25, color='grey')
plt.show()
